# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahirit/BIG-DATA-PROJECT/blob/master/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# Show the total number of columns and rows

# %%
df.shape
# Out:
# (3000, 9)

# %% [markdown]
# Show the total number of index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %% [markdown]
# Show the name of columns

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# Show the data type of each columns

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# Show the first (5) rows

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Show the last rows

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# Show the unique values

# %%
data =df["latitude"].unique()
data
# Out:
# array([37.37, 34.26, 33.78, 33.82, 36.33, 36.51, 38.63, 35.48, 38.4 ,
#        34.08, 33.98, 35.85, 37.25, 32.97, 33.73, 33.81, 37.53, 38.69,
#        34.21, 38.01, 37.75, 38.68, 34.07, 37.79, 33.28, 34.16, 37.76,
#        33.99, 34.01, 33.91, 39.31, 34.55, 33.94, 34.  , 37.97, 33.92,
#        33.93, 34.23, 36.2 , 32.77, 34.15, 34.09, 34.13, 33.17, 37.44,
#        38.  , 37.7 , 35.97, 37.8 , 33.8 , 38.72, 37.33, 37.56, 37.23,
#        40.87, 32.73, 37.69, 33.86, 34.04, 37.36, 39.5 , 37.49, 37.35,
#        34.2 , 34.17, 37.99, 37.4 , 34.05, 34.25, 38.26, 37.68, 36.74,
#        41.01, 37.62, 37.98, 33.87, 37.84, 36.64, 36.77, 38.42, 38.87,
#        33.77, 34.02, 38.62, 32.8 , 36.54, 38.52, 34.27, 37.74, 40.77,
#        33.63, 34.1 , 32.81, 37.34, 33.02, 37.3 , 38.55, 36.61, 33.84,
#        37.73, 37.96, 34.03, 34.71, 36.75, 40.46, 36.95, 39.49, 32.75,
#        39.28, 32.72, 37.54, 37.6 , 33.15, 37.72, 33.64, 32.79, 33.62,
# ...

# %%
print(sorted(data))
# Out:
# [32.56, 32.57, 32.58, 32.59, 32.6, 32.61, 32.62, 32.64, 32.66, 32.67, 32.68, 32.69, 32.7, 32.71, 32.72, 32.73, 32.74, 32.75, 32.76, 32.77, 32.78, 32.79, 32.8, 32.81, 32.82, 32.83, 32.84, 32.85, 32.86, 32.87, 32.88, 32.9, 32.91, 32.92, 32.93, 32.95, 32.96, 32.97, 32.98, 32.99, 33.0, 33.01, 33.02, 33.03, 33.04, 33.06, 33.07, 33.08, 33.09, 33.1, 33.11, 33.12, 33.13, 33.14, 33.15, 33.16, 33.17, 33.18, 33.19, 33.2, 33.21, 33.22, 33.26, 33.28, 33.29, 33.31, 33.42, 33.43, 33.44, 33.45, 33.46, 33.48, 33.49, 33.5, 33.51, 33.52, 33.53, 33.54, 33.55, 33.57, 33.58, 33.6, 33.61, 33.62, 33.63, 33.64, 33.65, 33.66, 33.67, 33.68, 33.69, 33.7, 33.71, 33.72, 33.73, 33.74, 33.75, 33.76, 33.77, 33.78, 33.79, 33.8, 33.81, 33.82, 33.83, 33.84, 33.85, 33.86, 33.87, 33.88, 33.89, 33.9, 33.91, 33.92, 33.93, 33.94, 33.95, 33.96, 33.97, 33.98, 33.99, 34.0, 34.01, 34.02, 34.03, 34.04, 34.05, 34.06, 34.07, 34.08, 34.09, 34.1, 34.11, 34.12, 34.13, 34.14, 34.15, 34.16, 34.17, 34.18, 34.19, 34.2, 34.21, 34.22, 34.2
# ...

# %%
df.nunique()
# Out:
# longitude              607
# latitude               587
# housing_median_age      52
# total_rooms           2215
# total_bedrooms        1055
# population            1802
# households            1026
# median_income         2578
# median_house_value    1784
# dtype: int64

# %%
df["latitude"].nunique()
# Out:
# 587

# %% [markdown]
# Show the median house value, where the price the  is less 10000.

# %%
df[df.median_house_value < 100000].value_counts()
# Out:
# longitude  latitude  housing_median_age  total_rooms  total_bedrooms  population  households  median_income  median_house_value
# -124.18    40.79     40.0                1398.0       311.0           788.0       279.0       1.4668         64600.0               1
# -124.16    40.77     35.0                2141.0       438.0           1053.0      434.0       2.8529         85600.0               1
# -119.02    35.38     52.0                90.0         35.0            36.0        31.0        0.8054         60000.0               1
#            35.36     48.0                1833.0       396.0           947.0       363.0       2.2827         70000.0               1
# -119.03    36.13     24.0                2259.0       408.0           1169.0      395.0       1.7106         95500.0               1
#                                                                                                                                   ..
# ...

# %%
df.sort_values(by = ["median_house_value"] , ascending = True)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2001    -117.16     32.71                52.0        845.0           451.0
# 1031    -123.08     40.40                10.0        365.0           102.0
# 2740    -119.97     36.44                18.0       1128.0           237.0
# 734     -117.65     35.00                36.0       1184.0           316.0
# 2555    -122.06     37.39                22.0       1236.0           290.0
# ...         ...       ...                 ...          ...             ...
# 1563    -118.44     33.98                21.0      18132.0          5419.0
# 1561    -122.06     37.27                16.0       1612.0           221.0
# 1510    -122.43     37.79                52.0       6186.0          1566.0
# 2738    -118.45     33.96                24.0       3097.0           791.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.sort_values(by = ["housing_median_age"] , ascending = True)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 842     -117.95     35.08                 1.0         83.0            15.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 2117    -117.51     34.16                 2.0        718.0            98.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 495     -122.29     37.82                 2.0        158.0            43.0
# ...         ...       ...                 ...          ...             ...
# 717     -122.27     37.86                52.0       2307.0           583.0
# 708     -118.21     33.97                52.0       4220.0           908.0
# 1826    -122.04     37.00                52.0       3365.0           644.0
# 754     -121.49     38.56                52.0       1777.0           368.0
# 1499    -122.21     37.79                52.0        762.0           190.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df["media"] = df["median_house_value"]* df["population"]
df.info()

df.head()

# %%
df["totalocupacion"] = df["total_rooms"] + df["total_bedrooms"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
#  9   media               3000 non-null   float64
#  10  totalocupacion      3000 non-null   float64
# dtypes: float64(11)
# memory usage: 257.9 KB

# %%
import matplotlib.pyplot as plt

df.plot(kind = "scatter", x = "totalocupacion", y ="media" )


plt.show()
